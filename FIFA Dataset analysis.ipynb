# %%
#loading the libraries

import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv('players_20.csv')
fifa.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
fifa.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            2036
# lcb           2036
# cb            2036
# rcb           2036
# rb            2036
# Length: 104, dtype: int64

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
#seeing all columns

for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
# Plotting a bar plot for nationality vs number of players from that country

plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]))
plt.show()

# %%
# Player Salary

player_salary=fifa[['short_name','wage_eur']]
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
#sorting the salary by descending order i

player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5])
# Out:
# <BarContainer object of 5 artists>

# %%
# Seeing how many players are from Germany

(fifa['nationality']=='Germany').value_counts()
# Out:
# False    17062
# True      1216
# Name: nationality, dtype: int64

# %%
# Seeing which players are from Germany

Germany=fifa[fifa['nationality']=='Germany']
Germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name  age         dob  height_cm  \
# 6   M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31       M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36       T. Kroos             Toni Kroos   29  1990-01-04        183
# 37        M. Reus             Marco Reus   30  1989-05-31        180
# 49     M. Hummels          Mats  Hummels   30  1988-12-16        191
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 6          85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# ...

# %%
#Sorting these german players by their height

Germany.sort_values(by=['height_cm'],ascending=True).head()
# Out:
#        sofifa_id                                         player_url  \
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
# 15960     247284  https://sofifa.com/player/247284/patrick-finge...
# 11380     250936  https://sofifa.com/player/250936/seref-ozcan/2...
# 6364      189209  https://sofifa.com/player/189209/sascha-bigalk...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
#
#           short_name         long_name  age         dob  height_cm  weight_kg  \
# 11612  K. Holzweiler  Kevin Holzweiler   24  1994-10-16        164         60
# 15960      P. Finger    Patrick Finger   18  2001-01-01        166         61
# 11380       S. Özcan       Seref Özcan   23  1996-06-08        166         65
# 6364      S. Bigalke    Sascha Bigalke   29  1990-01-08        167         60
# 17889      J. Gesien      Jakob Gesien   21  1998-01-11        167         58
#
#       nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
#Sorting these German players by their wages

Germany.sort_values(by=['wage_eur'],ascending=True).head()
# Out:
#        sofifa_id                                         player_url  \
# 18197     244172  https://sofifa.com/player/244172/matthis-harsm...
# 13253     234861  https://sofifa.com/player/234861/robin-ziegele...
# 13303     239668  https://sofifa.com/player/239668/jannes-voller...
# 13305     240000  https://sofifa.com/player/240000/elias-aboucha...
# 13312     241995  https://sofifa.com/player/241995/lars-dietz/20...
#
#            short_name          long_name  age         dob  height_cm  \
# 18197      M. Harsman    Matthis Harsman   19  1999-10-04        190
# 13253      R. Ziegele      Robin Ziegele   22  1997-03-13        186
# 13303      J. Vollert     Jannes Vollert   21  1998-01-21        186
# 13305  E. Abouchabaka  Elias Abouchabaka   19  2000-03-31        183
# 13312        L. Dietz         Lars Dietz   22  1997-01-07        190
#
#        weight_kg nationality                    club  ...   lwb   ldm   cdm  \
# ...

# %%
# Seeing only particular columns rather than seeing all columns

Selected_column=['short_name','wage_eur','sofifa_id']
Germany_selected_columns=Germany[selected_columns]
x=Germany_selected_columns.sort_values(by=['wage_eur'],ascending=False).head()
print(x)
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %%
# Other way of writing the above thing in a shorter manner
#Germany[['short_name','wage_eur']] this line actually means ki hum germany table se ye do column select kr rhe h jo isme stored data ko datafframe ki form me show ho rha h hume

Germany[['short_name','wage_eur','long_name']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur              long_name
# 36        T. Kroos    330000             Toni Kroos
# 6    M. ter Stegen    250000  Marc-André ter Stegen
# 55         L. Sané    195000             Leroy Sané
# 146    I. Gündoğan    180000         İlkay Gündoğan
# 70       T. Müller    170000          Thomas Müller

# %%
# Other way of writing the above thing in a shorter manner
#Germany[['short_name','wage_eur']] this line actually means ki hum germany table se ye do column select kr rhe h jo isme stored data ko datafframe ki form me show ho rha h hume
# Error isilie aaya kyuki ye data frame nhi only value de rha h hai

Germany['wage_eur'].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 4
#       1 # Other way of writing the above thing in a shorter manner
#       2 #Germany[['short_name','wage_eur']] this line actually means ki hum germany table se ye do column select kr rhe h jo isme stored data ko datafframe ki form me show ho rha h hume
# ----> 4 Germany['wage_eur'].sort_values(by=['wage_eur'],ascending=False).head()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
# SHOOTING

# %%
#for best shooting skills

player_shooting=fifa[['short_name','shooting']]
player_shooting.sort_values(by=['shooting'],ascending=False)
# Out:
#                short_name  shooting
# 1       Cristiano Ronaldo      93.0
# 0                L. Messi      92.0
# 12                H. Kane      91.0
# 17              S. Agüero      90.0
# 205       F. Quagliarella      89.0
# ...                   ...       ...
# 18231         P. Królczyk       NaN
# 18239          V. Storsve       NaN
# 18251  G. Sykes-Kenworthy       NaN
# 18259          H. Sveijer       NaN
# 18272           P. Martin       NaN
#
# [18278 rows x 2 columns]

# %%
#for best Defending skills

player_defend=fifa[['short_name','defending','club']]
player_defend.sort_values(by=['defending'],ascending=False)
# Out:
#                short_name  defending               club
# 16           G. Chiellini       90.0           Juventus
# 7             V. van Dijk       90.0          Liverpool
# 11           K. Koulibaly       89.0             Napoli
# 35               D. Godín       89.0              Inter
# 49             M. Hummels       89.0  Borussia Dortmund
# ...                   ...        ...                ...
# 18231         P. Królczyk        NaN      Piast Gliwice
# 18239          V. Storsve        NaN      Lillestrøm SK
# 18251  G. Sykes-Kenworthy        NaN      Bradford City
# 18259          H. Sveijer        NaN          IK Sirius
# 18272           P. Martin        NaN       Waterford FC
#
# [18278 rows x 3 columns]

# %%
# Extracting Info about Real Madrid
real_madrid=fifa[fifa['club']=='Real Madrid']
real_madrid.head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 28     192119  https://sofifa.com/player/192119/thibaut-court...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 28   T. Courtois     Thibaut Courtois   27  1992-05-11        199         96
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# ...

# %%
real_madrid.sort_values(by=['wage_eur'],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46        165153  https://sofifa.com/player/165153/karim-benzema...
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# 28        192119  https://sofifa.com/player/192119/thibaut-court...
# 106       198710  https://sofifa.com/player/198710/james-rodrigu...
# 76        201535  https://sofifa.com/player/201535/raphael-varan...
# 94        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# ...

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
#
#        short_name                    long_name  age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
# 46     K. Benzema                Karim Benzema   31  1987-12-19        185
# 161      L. Jović                   Luka Jović   21  1997-12-23        182
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 76      201535  https://sofifa.com/player/201535/raphael-varan...
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 332     240130  https://sofifa.com/player/240130/eder-gabriel-...
#
#        short_name                          long_name  age         dob  \
# 18   Sergio Ramos                Sergio Ramos García   33  1986-03-30
# 42       Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
# 76      R. Varane                     Raphaël Varane   26  1993-04-25
# 94       Carvajal              Daniel Carvajal Ramos   27  1992-01-11
# 332  Éder Militão               Éder Gabriel Militão   21  1998-01-18
#
#      height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# ...

# %%
(real_madrid['nationality'] =='spain').value_counts()
# Out:
# False    33
# Name: nationality, dtype: int64

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality, dtype: int64
